# %%
import pandas as pd

# %%
df.set_index(df['Date'],inplace=True)
a=df['Date'][df['Company ']=='GHI']
b=df['Price'][df['Company ']=='GHI']
c=xtest['Date'][xtest['Company ']=='GHI']
d=xtest['Price'][xtest['Company ']=='GHI']
b.shape
# Out:
# (3999,)

# %%
df=pd.read_csv(r'C:\Users\Abhinandu Reddy\Desktop\wpi cpi\dataset\train.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
b.plot()

# %%
df['Price'][10:].plot()

# %%
df.drop(['ID'],inplace=True,axis=1)
df.drop([730],inplace=True,axis=0)
y=df['Price']
df['Price'].unique()
# Out:
# array([ 18.81,  57.5 , 135.25, ..., 384.49, 560.02, 386.95])

# %%
df["Date"].unique().shape
# Out:
# (3996,)

# %%
df.dropna(inplace=True)

# %%
df['Company '].unique()
# Out:
# array(['ABC', 'DEF', 'GHI'], dtype=object)

# %%
def oneHotEncode(df,colNames):
    for col in colNames:
        if( df[col].dtype == np.dtype('object')):
            dummies = pd.get_dummies(df[col],prefix=col)
            df = pd.concat([df,dummies],axis=1)

            #drop the encoded column
            df.drop([col],axis = 1 , inplace=True)
    return df

# %%
import numpy as np
df.columns.shape
# Out:
# (68,)

# %%
df=oneHotEncode(df,df.columns)

# %%
import keras

# %%
df.columns
# Out:
# Index(['SMA', 'EMA', 'WMA', 'DEMA', 'TEMA', 'TRIMA', 'KAMA', 'FAMA', 'MAMA',
#        'T3',
#        ...
#        'Date_31-12-2153', 'Date_31-12-2154', 'Date_31-12-2157',
#        'Date_31-12-2158', 'Date_31-12-2159', 'Date_31-12-2160',
#        'Date_31-12-2162', 'Company _ABC', 'Company _DEF', 'Company _GHI'],
#       dtype='object', length=4011)

# %%
y=df["Price"]

# %%
df.drop(['Date','Company '],inplace=True,axis=1)

# %%
x=df

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(df,y,test_size=0.01,random_state=40)
print(xtrain.shape,xtest.shape,ytrain.shape,ytest.shape)
# Out:
# (11877, 67) (120, 67) (11877,) (120,)

# %%
ytrain[0:0]
# Out:
# Series([], Name: Price, dtype: float64)

# %%
X_train = []
y_train = []
for i in range(60, 2035):
    X_train.append(xtrain[i-60:i,:])
    y_train.append(ytrain[i: 0])
X_train, y_train = np.array(X_train), np.array(y_train)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
x=xtrain
y=ytrain

# %%
x.head()
# Out:
#            SMA       EMA       WMA      DEMA      TEMA     TRIMA      KAMA  \
# 2116   29.9580   31.3279   31.8095   32.3241   34.0370   30.7873   29.2558
# 9298  133.1372  133.0322  131.1684  129.4095  128.0986  131.9787  133.2484
# 3346   17.5000   17.5885   17.5758   17.3927   17.3381   17.7067   17.3424
# 1322   92.4430   92.5332   92.7122   93.0821   92.2654   92.9993   92.7260
# 4922   28.3297   28.4296   28.5209   28.5788   28.7002   28.4337   28.3447
#
#          FAMA      MAMA        T3   ...            OBV  HT_TRENDLINE  \
# 2116  80.4454   49.9471   27.6749   ...    119526533.0       33.6829
# 9298  87.0098  118.4611  135.8725   ...    755972486.0      138.7497
# 3346  26.0581   15.0983   17.5389   ...    171046733.0       18.2680
# 1322  87.0109   98.2831   92.3232   ...    440111700.0       93.0296
# 4922  35.4790   27.5104   28.2558   ...    985405450.0       28.1261
#
#       LEAD SINE    SINE  TRENDMODE  DCPERIOD  HT_DCPHASE    PHASE  QUADRATURE  \
# 2116     0.9545  0.4640        1.0   32.8424     27.6439   8.8685      5.7972
# 9298    -0.4490 -0.9493        1.0   27.5012    288.3204 -11.2716     -6.0732
# 3346     0.6453 -0.0839        1.0   30.8222     -4.8144   0.7742      3.4864
# 1322     0.8893  0.9522        0.0   19.8371     72.2103   2.5192      0.2645
# 4922     0.9977  0.6573        1.0   27.1678     41.0980   0.2895      1.6131
#
#        Price
# 2116   37.38
# 9298  131.47
# 3346   15.85
# 1322   88.06
# 4922   28.58
#
# [5 rows x 66 columns]

# %%
x.columns[x.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
miss = x.isnull().sum()/len(x)
miss = miss[miss > 0]
miss.sort_values(inplace=True)
miss
# Out:
# Series([], dtype: float64)

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0)
import seaborn as sns
from scipy import stats
from scipy.stats import norm

# %%
sns.distplot(y)
# Out:
# C:\Users\Abhinandu Reddy\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
target = np.log(y)
print ('Skewness is', target.skew())
sns.distplot(target)
# Out:
# Skewness is 0.5662594294799641
# C:\Users\Abhinandu Reddy\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
numeric_data = x.select_dtypes(include=[np.number])
cat_data = x.select_dtypes(exclude=[np.number])
print ("There are {} numeric and {} categorical columns in train data".format(numeric_data.shape[1],cat_data.shape[1]))
# Out:
# There are 66 numeric and 0 categorical columns in train data

# %%
corr = numeric_data.corr()
plt.figure(figsize=(15,8))

sns.heatmap(corr)

# %%
numeric_data.head()
# Out:
#         ID       SMA       EMA       WMA      DEMA      TEMA     TRIMA  \
# 4812  4813   27.7690   27.8897   28.0538   28.3526   28.5236   27.8867
# 1286  1287   94.0360   93.2844   93.4502   93.6913   91.7724   94.6067
# 9405  9406  265.8041  260.9481  261.4137  258.2692  253.8511  266.6801
# 537    538   37.6510   37.8727   38.0609   38.1550   38.2630   37.9537
# 8607  8608  140.9170  139.4404  141.3345  142.5459  141.7937  142.0203
#
#           KAMA      FAMA      MAMA   ...             OBV  HT_TRENDLINE  \
# 4812   27.1897   20.8606   23.9053   ...    2.603571e+08       27.0405
# 1286   92.7463   86.2930   99.0584   ...    4.695527e+08       93.8329
# 9405  261.3081  163.5719  221.1079   ...    2.401380e+09      265.9827
# 537    38.0559    9.6287   26.8996   ...    1.899106e+08       37.4786
# 8607  141.5201  125.9155  118.6088   ...    1.781222e+09      133.3447
#
#       LEAD SINE    SINE  TRENDMODE  DCPERIOD  HT_DCPHASE   PHASE  QUADRATURE  \
# 4812    -0.5818  0.1637        1.0   23.8331    170.5787  1.1176      1.1038
# 1286    -0.9956 -0.6378        1.0   20.7632    219.6263  2.0854     -1.2275
# 9405    -0.4521 -0.9504        1.0   13.7582    288.1191 -3.3479     -6.5702
# 537      0.2653  0.8693        1.0   17.3380    119.6172  1.3813      1.3169
# 8607    -0.8314 -0.1949        1.0   20.2494    191.2390  5.7687     -0.3290
#
#        Price
# 4812   28.78
# 1286   89.50
# 9405  248.63
# 537    35.06
# 8607  136.09
#
# [5 rows x 67 columns]

# %%
plt.scatter(df['FAMA'],df['Price'])

# %%
cat_data.describe()
# Out:
#               Date Company
# count         8397     8397
# unique        3906        3
# top     28-02-2150      GHI
# freq             4     2809

# %%
sp_pivot = df.pivot_table(index='Company ', values='Price', aggfunc=np.median)
sp_pivot
# Out:
#            Price
# Company
# ABC       76.089
# DEF       66.990
# GHI       29.040

# %%
num = [f for f in df.columns if df.dtypes[f] != 'object']

nd = pd.melt(x, value_vars = num)
n1 = sns.FacetGrid (nd, col='variable', col_wrap=4, sharex=False, sharey = False)
n1 = n1.map(sns.distplot, 'value')
n1

# %%
a=df['SMA']>200
b=df['Price']<200
df[a & b]
# Out:
#              Date Company        SMA       EMA       WMA      DEMA      TEMA  \
# 670    03-12-2148      DEF  200.5800  193.5439  204.5509  212.4250  210.7588
# 10474  197.7380  200.7327  157.8380   ...     8.643543e+08      208.2800
#
#        LEAD SINE    SINE  TRENDMODE  DCPERIOD  HT_DCPHASE     PHASE  \
# 670      -0.3613  0.4038        1.0   30.3300    156.1815   64.2504
# 673      -0.4439  0.3197        1.0   29.4038    161.3557   38.6522
# 733      -0.8517 -0.2318        1.0   22.2897    193.4003   21.2545
# 736      -0.9461 -0.4401        1.0   23.1201    206.1097   21.9462
# 739      -0.9961 -0.6418        1.0   23.5378    219.9225   13.7964
# 742      -0.9775 -0.8403        1.0   23.5692    237.1671  -26.9038
# 745      -0.8845 -0.9553        1.0   23.9909    252.8130  -43.6290
# 748      -0.7984 -0.9903        1.0   24.7760    262.0193 -169.3029
# 751      -0.7025 -1.0000        1.0   25.9635    270.3720 -237.5702
# 8943     -0.3701  0.3952        1.0   16.9340    156.7223    7.8670
# 8958     -0.9649 -0.8680        1.0   16.0502    240.2270    0.5080
# 8961     -0.8793 -0.9586        0.0   16.1092    253.4469   -2.9773
# 8964     -0.7157 -0.9999        0.0   16.2441    269.3026   -3.1424
# 8967     -0.4004 -0.9311        0.0   16.4557    291.3961   -0.1610
# 8970     -0.2779 -0.8758        1.0   16.6494    298.8642    1.1353
# 8973      0.1295 -0.6096        1.0   16.7817    -37.5611   -0.8854
# 8976      0.3452 -0.4195        1.0   16.9170    -24.8050   -2.8782
# 9066     -0.9800 -0.8336        1.0   23.2062    236.4754   -3.9488
# 9078     -0.2707 -0.8721        1.0   22.3594    299.2968    2.4665
# 9081      0.0832 -0.6458        1.0   22.1216    -40.2252    2.8793
# 9084      0.3138 -0.4495        1.0   22.0660    -26.7131   -2.8466
# 9087      0.3398 -0.4247        1.0   22.4171    -25.1334   -7.2940
# 9090      0.2858 -0.4755        1.0   23.4157    -28.3949   -6.8648
# 9093      0.2714 -0.4887        1.0   24.2376    -29.2537   -3.2509
# 9096      0.3434 -0.4213        1.0   24.2241    -24.9169   -2.6463
# 10060    -0.8070 -0.1530        1.0   20.9947    188.8022    1.8541
# 10063    -0.8656 -0.2580        1.0   21.3240    194.9531    0.5096
# 10066    -0.9016 -0.3317        1.0   21.8298    199.3742    2.0651
# 10234    -0.9966 -0.6468        1.0   27.3174    220.3042    6.2980
# 10240    -0.9314 -0.9160        1.0   27.0085    246.3509   -0.8637
# 10243    -0.8076 -0.9881        1.0   26.5062    261.1423  -10.4992
# 10252    -0.2697 -0.8716        1.0   26.8518    299.3522  -20.9870
# 10255    -0.0459 -0.7388        1.0   26.2233    312.3696  -17.9724
# 10258     0.1795 -0.5687        1.0   25.2588    -34.6616   -8.5687
# 10402    -0.4897  0.2703        1.0   21.9768    164.3204    7.4421
# 10453     0.1058  0.7780        0.0   18.2444    128.9262   -3.1212
# 10456    -0.9688 -0.5098        1.0   18.0134    210.6519   -3.4586
# 10459    -0.7943 -0.9912        1.0   17.8245    262.4088   -1.6180
# 10462    -0.4945 -0.9643        1.0   17.6675    285.3638    1.6086
# 10465    -0.2237 -0.8473        1.0   17.5353    302.0757    1.4375
# 10468     0.1008 -0.6322        1.0   17.4621    -39.2119   -2.6986
# 10471     0.2221 -0.5324        1.0   17.5849    -32.1686   -9.1055
# 10474     0.4008 -0.3644        1.0   18.1521    -21.3691  -16.8701
#
#        QUADRATURE    Price
# 670      -67.9089  188.500
# 673      -85.6212  191.000
# 733      -34.5618  138.000
# 736      -31.2484  158.900
# 739     -114.6682  160.300
# 742     -137.4647  184.600
# 745     -228.9711  163.400
# 748     -290.1384  148.000
# 751       32.0570  138.000
# 8943      -5.8062  199.920
# 8958      -5.3023  199.910
# 8961      -3.9398  196.970
# 8964       2.4049  196.230
# 8967       3.8103  196.480
# 8970      -0.5538  193.320
# 8973      -4.0790  188.950
# 8976      -1.5776  189.870
# 9066       1.3094  197.750
# 9078       2.3706  199.290
# 9081      -8.1754  192.063
# 9084     -13.4025  194.730
# 9087      -6.1439  195.860
# 9090       3.6638  199.230
# 9093       3.8882  192.050
# 9096      -3.2238  195.460
# 10060     -3.6355  192.510
# 10063     -0.2406  194.810
# 10066      5.2362  197.090
# 10234    -12.8173  193.700
# 10240    -29.7619  194.130
# 10243    -31.8990  198.360
# 10252      5.8817  197.680
# 10255     22.5598  195.930
# 10258     25.2496  182.520
# 10402    -18.7861  198.400
# 10453     -4.1853  197.140
# 10456      1.3642  189.250
# 10459      4.9522  192.340
# 10462      2.1938  188.990
# 10465     -6.9504  182.399
# 10468    -14.6328  194.150
# 10471    -18.0427  188.390
# 10474    -14.8811  192.290
#
# [43 rows x 68 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x=x.fillna(0)
xtest=xtest.fillna(0)
y=y.fillna(0)
ytest=ytest.fillna(0)

# %%
from sklearn.linear_model import Ridge,Lasso

# %%
reg = Ridge().fit(x[['TEMA','DEMA','WMA','EMA','SMA','TRIMA','KAMA','T3','Real Lower Band','Real Middle Band','HT_TRENDLINE','MAMA']], y)

# %%
yp=reg.predict(xtest[['TEMA','DEMA','WMA','EMA','SMA','TRIMA','KAMA','T3','Real Lower Band','Real Middle Band','HT_TRENDLINE','MAMA']])

# %%
from sklearn.metrics import r2_score
r2_score((ytest), yp)
# Out:
# 0.996442594028551

# %%
print (corr['Price'].sort_values(ascending=False)[:20], '\n') #top 15 values
print ('----------------------')
print (corr['Price'].sort_values(ascending=False)[-10:]) #last 5 values`
0.99815341394789
0.998430569443508
# Out:
# Price               1.000000
# TEMA                0.998963
# DEMA                0.998718
# WMA                 0.998331
# EMA                 0.998121
# SMA                 0.997634
# TRIMA               0.997407
# KAMA                0.997370
# T3                  0.996937
# Real Lower Band     0.996250
# Real Middle Band    0.996031
# HT_TRENDLINE        0.994697
# MAMA                0.976812
# FAMA                0.927866
# OBV                 0.687668
# PLUS_DM             0.627276
# Chaikin A/D         0.516136
# MINUS_DM            0.492808
# MACD                0.246037
# APO                 0.150610
# Name: Price, dtype: float64
#
# ----------------------
# MIDPOINT     -0.001821
# ATR          -0.003993
# DCPERIOD     -0.004241
# MACD_Hist    -0.007192
# BOP          -0.014234
# MAC_Hist     -0.015896
# TRENDMODE    -0.019399
# SINE         -0.030641
# Aroon Down   -0.064204
# LEAD SINE    -0.075112
# Name: Price, dtype: float64

# %%
sam=pd.read_csv(r'C:\Users\Abhinandu Reddy\Desktop\wpi cpi\dataset\Sample_Submission.csv')

# %%
sam.head()
# Out:
#       ID  Price
# 0  12001      0
# 1  12002      0
# 2  12003      0
# 3  12004      0
# 4  12005      0

# %%
test=pd.read_csv(r'C:\Users\Abhinandu Reddy\Desktop\wpi cpi\dataset\test.csv')

# %%
test.head()
# Out:
#       ID        Date Company       SMA       EMA       WMA      DEMA  \
# 0  12001  09-12-2163      ABC  551.207  553.3926  559.2131  567.0388
# 1  12002  09-12-2163      DEF  385.975  384.0682  387.7373  391.4103
# 2  12003  09-12-2163      GHI   38.116   38.1516   38.2909   38.5057
# 3  12004  10-12-2163      ABC  555.463  555.2449  561.4627  567.9254
# 4  12005  10-12-2163      DEF  386.967  384.0086  387.3309  389.9669
#
#        TEMA     TRIMA      KAMA     ...             ADOSC         OBV  \
# 0  570.5996  554.3346  560.7553     ...     -2.038989e+06  2594606100
# 1  390.3597  388.0083  381.3179     ...      8.652003e+05   961165686
# 2   38.6109   38.1000   37.8252     ...      2.035506e+07 -2042164174
# 3  570.0487  558.9843  561.3335     ...     -1.370708e+06  2584667900
# 4  387.9751  388.2523  381.3996     ...      1.188655e+06   963902486
#
#    HT_TRENDLINE  LEAD SINE    SINE  TRENDMODE  DCPERIOD  HT_DCPHASE    PHASE  \
# 0      531.2224    -0.0518  0.6695          1   25.7849    137.9718  34.4973
# 1      371.0374    -0.8132 -0.1634          1   21.2438    189.4060  17.5922
# 2       37.6903    -0.1467  0.5958          1   19.6563    143.4333   0.3742
# 3      532.6439    -0.1763  0.5714          1   26.4483    145.1522  32.5341
# 4      372.0115    -0.8503 -0.2290          1   21.5579    193.2403  12.3675
#
#    QUADRATURE
# 0     10.5310
# 1     -7.5945
# 2      0.3351
# 3    -12.1039
# 4    -26.7711
#
# [5 rows x 68 columns]

# %%
ypt=reg.predict(test[['TEMA','DEMA','WMA','EMA','SMA','TRIMA','KAMA','T3','Real Lower Band','Real Middle Band','HT_TRENDLINE','MAMA']])

# %%
sam.shape
# Out:
# (4161, 2)

# %%
test.shape
# Out:
# (4161, 68)

# %%
if sam['ID'].all()==test['ID'].all():
    print('s')
# Out:
# s

# %%
sam['Price']=ypt

# %%
sam.to_csv('samplle')

# %%
ysvrp=clf.predict(xtest[['TEMA','DEMA','WMA','EMA','SMA','TRIMA','KAMA','T3','Real Lower Band','Real Middle Band','HT_TRENDLINE']])

# %%
r2_score(ytest, ysvrp)

# %%
import tensorflow as tf
model=tf.keras.models.Sequential([tf.keras.layers.Dense(10,activation=tf.nn.relu),tf.keras.layers.Dense(10,activation=tf.nn.relu),tf.keras.layers.Dense(1)])
model.compile(optimizer=tf.train.GradientDescentOptimizer(0.001),loss='mean_squared_error',metrics=['accuracy'])
model.fit(x[['TEMA','DEMA','WMA','EMA','SMA','TRIMA','KAMA','T3','Real Lower Band','Real Middle Band','HT_TRENDLINE']],ytrain,epochs=20)
model.evaluate(xtest[['TEMA','DEMA','WMA','EMA','SMA','TRIMA','KAMA','T3','Real Lower Band','Real Middle Band','HT_TRENDLINE']],ytest)

# %%
test[['TEMA','DEMA','WMA','EMA','SMA','TRIMA','KAMA','T3','Real Lower Band','Real Middle Band','HT_TRENDLINE']][0:2].values
# Out:
# array([[570.5996, 567.0388, 559.2131, 553.3926, 551.207 , 554.3346,
#         560.7553, 545.9371, 516.9314, 551.207 , 531.2224],
#        [390.3597, 391.4103, 387.7373, 384.0682, 385.975 , 388.0083,
#         381.3179, 385.9426, 372.7517, 385.975 , 371.0374]])
